# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('/content/apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.shape
# Out:
# (10841, 12)

# %%
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')

# %%
df_apps.sample(5)
# Out:
#                                              App             Category  Rating  \
# 10747                             Microsoft Word         PRODUCTIVITY    4.50
# 8684   League of Gamers - Be an E-Sports Legend!               SPORTS    4.50
# 3083                  USMLE Step 2 CK Cards Lite               FAMILY    4.00
# 3742                                 B&H Kids AR  BOOKS_AND_REFERENCE    3.90
# 1135                         PK and DK Audio App               FAMILY    5.00
#
#        Reviews  Size_MBs     Installs  Type Price Content_Rating  \
# 10747  2084126      4.00  500,000,000  Free     0       Everyone
# 8684     68072     40.00    5,000,000  Free     0       Everyone
# 3083        28      1.50        5,000  Free     0       Everyone
# 3742       286     18.00       10,000  Free     0       Everyone
# 1135         2      3.90          100  Free     0       Everyone
#
#                   Genres        Last_Updated Android_Ver
# ...

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps.drop(['Last_Updated','Android_Ver'], axis=1, inplace=True)

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
df_apps.Rating.isna().values.sum()
# Out:
# 1474

# %%
df_apps_clean = df_apps.dropna()

# %%
df_apps_clean.shape
# Out:
# (9367, 10)

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
df_apps_clean.duplicated().values.sum()
# Out:
# 476

# %%
duplicated_rows = df_apps_clean[df_apps_clean.duplicated()]

# %%
duplicated_rows.head()
# Out:
#                                              App Category  Rating  Reviews  \
# 946                       420 BZ Budeze Delivery  MEDICAL    5.00        2
# 1133                                 MouseMingle   DATING    2.70        3
# 1196  Cardiac diagnosis (heart rate, arrhythmia)  MEDICAL    4.40        8
# 1231                                Sway Medical  MEDICAL    5.00        3
# 1247              Chat Kids - Chat Room For Kids   DATING    4.70        6
#
#       Size_MBs Installs  Type   Price Content_Rating   Genres
# 946      11.00      100  Free       0     Mature 17+  Medical
# 1133      3.90      100  Free       0     Mature 17+   Dating
# 1196      6.50      100  Paid  $12.99       Everyone  Medical
# 1231     22.00      100  Free       0       Everyone  Medical
# 1247      4.90      100  Free       0     Mature 17+   Dating

# %%
df_apps_clean[df_apps_clean.App == 'Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10808  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 10809  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social
# 10808     0           Teen  Social
# 10809     0           Teen  Social
# 10810     0           Teen  Social

# %%
df_non_duplicates = df_apps_clean.drop_duplicates()
print(df_non_duplicates)
# Out:
#                                                    App Category  Rating  \
# 21                                 KBA-EZ Health Guide  MEDICAL    5.00
# 28                                            Ra Ga Ba     GAME    5.00
# 47                                             Mu.F.O.     GAME    5.00
# 82                                    Brick Breaker BR     GAME    5.00
# 99     Anatomy & Physiology Vocabulary Exam Review App  MEDICAL    5.00
# ...                                                ...      ...     ...
# 10835                                   Subway Surfers     GAME    4.50
# 10836                                   Subway Surfers     GAME    4.50
# 10837                                   Subway Surfers     GAME    4.50
# 10838                                   Subway Surfers     GAME    4.50
# 10840                                   Subway Surfers     GAME    4.50
#
#         Reviews  Size_MBs       Installs  Type  Price Content_Rating   Genres
# ...

# %%
df_non_duplicates.shape
# Out:
# (8891, 10)

# %%
df_non_duplicates[df_non_duplicates.App == 'Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10808  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social
# 10808     0           Teen  Social
# 10810     0           Teen  Social

# %%
df_non_duplicates = df_non_duplicates.drop_duplicates(subset=['App', 'Type', 'Price'])

# %%
df_non_duplicates.shape
# Out:
# (8199, 10)

# %%
df_non_duplicates[df_non_duplicates.App == 'Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_non_duplicates.sort_values('Rating',ascending=False)
# Out:
#                                           App      Category  Rating  Reviews  \
# 21                        KBA-EZ Health Guide       MEDICAL    5.00        4
# 1230                             Sway Medical       MEDICAL    5.00        3
# 1227                        AJ Men's Grooming     LIFESTYLE    5.00        2
# 1224                           FK Dedinje BGD        SPORTS    5.00       36
# 1223                          CB VIDEO VISION   PHOTOGRAPHY    5.00       13
# ...                                       ...           ...     ...      ...
# 1314                              CR Magazine      BUSINESS    1.00        1
# 1932           FE Mechanical Engineering Prep        FAMILY    1.00        2
# 357                         Speech Therapy: F        FAMILY    1.00        1
# 818   Familial Hypercholesterolaemia Handbook       MEDICAL    1.00        2
# 1208                           Thistletown CI  PRODUCTIVITY    1.00        1
#
# ...

# %%
df_non_duplicates.sort_values(['Rating','Reviews'], ascending=False)
# Out:
#                                                     App      Category  Rating  \
# 2095                                         Ríos de Fe     LIFESTYLE    5.00
# 2438  FD Calculator (EMI, SIP, RD & Loan Eligilibility)       FINANCE    5.00
# 3115                                         Oración CX     LIFESTYLE    5.00
# 2107                     Barisal University App-BU Face        FAMILY    5.00
# 2069                                         Master E.K        FAMILY    5.00
# ...                                                 ...           ...     ...
# 728                       Truck Driving Test Class 3 BC        FAMILY    1.00
# 1208                                     Thistletown CI  PRODUCTIVITY    1.00
# 1271                                             MbH BM       MEDICAL    1.00
# 1314                                        CR Magazine      BUSINESS    1.00
# 2416                   BJ Bridge Standard American 2018          GAME    1.00
#
# ...

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_non_duplicates.sort_values('Size_MBs', ascending=False).head()
# Out:
#                                   App            Category  Rating  Reviews  \
# 9942   Talking Babsy Baby: Baby Games           LIFESTYLE    4.00   140995
# 10687          Hungry Shark Evolution                GAME    4.50  6074334
# 9943            Miami crime simulator                GAME    4.00   254518
# 9944     Gangster Town: Vice District              FAMILY    4.30    65146
# 3144                       Vi Trainer  HEALTH_AND_FITNESS    3.60      124
#
#        Size_MBs     Installs  Type Price Content_Rating  \
# 9942     100.00   10,000,000  Free     0       Everyone
# 10687    100.00  100,000,000  Free     0           Teen
# 9943     100.00   10,000,000  Free     0     Mature 17+
# 9944     100.00   10,000,000  Free     0     Mature 17+
# 3144     100.00        5,000  Free     0       Everyone
#
#                        Genres
# 9942   Lifestyle;Pretend Play
# 10687                  Arcade
# 9943                   Action
# 9944               Simulation
# ...

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_non_duplicates.sort_values('Reviews',ascending=False).head()
# Out:
#                                             App       Category  Rating  \
# 10805                                  Facebook         SOCIAL    4.10
# 10785                        WhatsApp Messenger  COMMUNICATION    4.40
# 10806                                 Instagram         SOCIAL    4.50
# 10784  Messenger – Text and Video Chat for Free  COMMUNICATION    4.00
# 10650                            Clash of Clans           GAME    4.60
#
#         Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 10805  78158306      5.30  1,000,000,000  Free     0           Teen
# 10785  69119316      3.50  1,000,000,000  Free     0       Everyone
# 10806  66577313      5.30  1,000,000,000  Free     0           Teen
# 10784  56642847      3.50  1,000,000,000  Free     0       Everyone
# 10650  44891723     98.00    100,000,000  Free     0   Everyone 10+
#
#               Genres
# 10805         Social
# 10785  Communication
# 10806         Social
# 10784  Communication
# ...

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
ratings_1 = df_non_duplicates.groupby('Content_Rating')['Content_Rating'].count()
print(ratings_1)
# Out:
# Content_Rating
# Adults only 18+       3
# Everyone           6621
# Everyone 10+        305
# Mature 17+          357
# Teen                912
# Unrated               1
# Name: Content_Rating, dtype: int64

# %%
ratings = df_non_duplicates.value_counts('Content_Rating')
print(ratings)
# Out:
# Content_Rating
# Everyone           6621
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# dtype: int64

# %%
import plotly.express as px
fig = px.pie(labels=ratings.index, values=ratings.values)
fig.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py:137: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   return args["labels"][column]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(labels=ratings.index, values=ratings.values,title= "Content Rating", names=ratings.index)
fig.update_traces(textposition='outside', textinfo= 'percent+label')
fig.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py:137: FutureWarning:
#
# Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(labels=ratings.index,
             values=ratings.values,
             title= "Content Rating",
             names=ratings.index,
             hole=0.5)
fig.update_traces(textposition='outside', textinfo= 'percent+label')
fig.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py:137: FutureWarning:
#
# Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
df_non_duplicates.reset_index(drop=True,inplace=True)
type(df_non_duplicates['Installs'][0])
df_non_duplicates.sort_values('Installs',ascending=False).head()
# Out:
#                                                     App       Category  \
# 8161                                     My Talking Tom           GAME
# 8167  Security Master - Antivirus, VPN, AppLock, Boo...          TOOLS
# 8155                         SHAREit - Transfer & Share          TOOLS
# 8156                      imo free video calls and chat  COMMUNICATION
# 8157                                                Pou           GAME
#
#       Rating   Reviews  Size_MBs     Installs  Type Price Content_Rating  \
# 8161    4.50  14891223     36.00  500,000,000  Free     0       Everyone
# 8167    4.70  24900999      3.40  500,000,000  Free     0       Everyone
# 8155    4.60   7790693     17.00  500,000,000  Free     0       Everyone
# 8156    4.30   4785892     11.00  500,000,000  Free     0       Everyone
# 8157    4.30  10485308     24.00  500,000,000  Free     0       Everyone
#
#              Genres
# 8161         Casual
# 8167          Tools
# 8155          Tools
# ...

# %%
df_non_duplicates.value_counts('Installs')
# Out:
# Installs
# 1,000,000        1417
# 100,000          1096
# 10,000            988
# 10,000,000        933
# 1,000             698
# 5,000,000         607
# 500,000           504
# 50,000            457
# 5,000             425
# 100               303
# 50,000,000        202
# 500               199
# 100,000,000       189
# 10                 69
# 50                 56
# 500,000,000        24
# 1,000,000,000      20
# 5                   9
# 1                   3
# dtype: int64

# %%
df_non_duplicates['Installs'] = df_non_duplicates['Installs'].str.replace(',','')
print(df_non_duplicates.Installs.sample(5))
# Out:
# 3857    100000
# 1839     10000
# 2017     10000
# 171        100
# 2319     10000
# Name: Installs, dtype: object

# %%
df_non_duplicates['Installs'] = df_non_duplicates["Installs"].astype(int)
type(df_non_duplicates['Installs'][0])
# Out:
# numpy.int64

# %%
df_non_duplicates[df_non_duplicates.Installs >= 100000000].Installs.count()
# Out:
# 233

# %%
df_non_duplicates.value_counts('Installs').sort_index()
# Out:
# Installs
# 1                3
# 5                9
# 10              69
# 50              56
# 100            303
# 500            199
# 1000           698
# 5000           425
# 10000          988
# 50000          457
# 100000        1096
# 500000         504
# 1000000       1417
# 5000000        607
# 10000000       933
# 50000000       202
# 100000000      189
# 500000000       24
# 1000000000      20
# dtype: int64

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_non_duplicates.Price.sample(5)
# Out:
# 8020    0
# 7057    0
# 1618    0
# 3593    0
# 4645    0
# Name: Price, dtype: object

# %%
type(df_non_duplicates.Price[0])
# Out:
# str

# %%
df_non_duplicates['Price'] = df_non_duplicates['Price'].str.replace('$','')
# Out:
# <ipython-input-38-c812dedf80c0>:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
df_non_duplicates.Price.sample(5)
# Out:
# 2580    0
# 7926    0
# 5932    0
# 8000    0
# 2048    0
# Name: Price, dtype: object

# %%
df_non_duplicates['Price'] = pd.to_numeric(df_non_duplicates['Price'])

# %%
type(df_non_duplicates['Price'][0])
# Out:
# numpy.float64

# %%
df_non_duplicates[['App','Price']].sort_values('Price',ascending=False).head(20)
# Out:
#                                  App  Price
# 2466        I'm Rich - Trump Edition 400.00
# 1143              I AM RICH PRO PLUS 399.99
# 3095               I Am Rich Premium 399.99
# 1719              I am rich(premium) 399.99
# 2101                      💎 I'm rich 399.99
# 4185                       I am rich 399.99
# 753   I am rich (Most expensive app) 399.99
# 1396                   I Am Rich Pro 399.99
# 1793                  I am Rich Plus 399.99
# 1688                       I am Rich 399.99
# 370           most expensive app (H) 399.99
# 1094                      I am Rich! 399.99
# 2423                       I Am Rich 389.99
# 944              I am extremely Rich 379.99
# 2387                   I am rich VIP 299.99
# 1012       Vargo Anesthesia Mega App  79.99
# 408                     LTC AS Legal  39.99
# 1267                I am Rich Person  37.99
# 1158         A Manual of Acupuncture  33.99
# 2770         Golfshot Plus: Golf GPS  29.99

# %% [markdown]
# ### The most expensive apps sub $250

# %%
df_non_duplicates[df_non_duplicates.Price > 250][['App','Price']]
# Out:
#                                  App  Price
# 370           most expensive app (H) 399.99
# 753   I am rich (Most expensive app) 399.99
# 944              I am extremely Rich 379.99
# 1094                      I am Rich! 399.99
# 1143              I AM RICH PRO PLUS 399.99
# 1396                   I Am Rich Pro 399.99
# 1688                       I am Rich 399.99
# 1719              I am rich(premium) 399.99
# 1793                  I am Rich Plus 399.99
# 2101                      💎 I'm rich 399.99
# 2387                   I am rich VIP 299.99
# 2423                       I Am Rich 389.99
# 2466        I'm Rich - Trump Edition 400.00
# 3095               I Am Rich Premium 399.99
# 4185                       I am rich 399.99

# %%
indices_to_drop = df_non_duplicates[(df_non_duplicates.Price > 250)].index

# %%
df_non_duplicates.drop(indices_to_drop, inplace=True)

# %%
df_non_duplicates[df_non_duplicates.Price > 250][['App','Price']]
# Out:
# Empty DataFrame
# Columns: [App, Price]
# Index: []

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df_non_duplicates['Revenue'] = df_non_duplicates.Price * df_non_duplicates.Installs

# %%
df_non_duplicates['Revenue'].sample(5)
# Out:
# 2124   0.00
# 5693   0.00
# 391    0.00
# 3672   0.00
# 4522   0.00
# Name: Revenue, dtype: float64

# %%
df_non_duplicates[['App','Revenue']].sort_values('Revenue',ascending=False).head(10)
# Out:
#                                 App       Revenue
# 7142                      Minecraft 69,900,000.00
# 6871                  Hitman Sniper  9,900,000.00
# 5439  Grand Theft Auto: San Andreas  6,990,000.00
# 5736            Facetune - For Free  5,990,000.00
# 6194        Sleep as Android Unlock  5,990,000.00
# 4941            DraStic DS Emulator  4,990,000.00
# 4472                   Weather Live  2,995,000.00
# 6171                    Bloons TD 5  2,990,000.00
# 5874        Five Nights at Freddy's  2,990,000.00
# 5079     Card Wars - Adventure Time  2,990,000.00

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
df_non_duplicates.Category.nunique()
# Out:
# 33

# %%
no_of_apps_per_category = df_non_duplicates.value_counts('Category')
print(no_of_apps_per_category[:10])
# Out:
# Category
# FAMILY             1606
# GAME                910
# TOOLS               719
# PRODUCTIVITY        301
# PERSONALIZATION     298
# LIFESTYLE           297
# FINANCE             296
# MEDICAL             292
# PHOTOGRAPHY         263
# BUSINESS            262
# dtype: int64

# %%
no_of_installations_per_category = df_non_duplicates.groupby('Category').agg({'Installs' : pd.Series.sum})
no_of_installations_per_category.sort_values(by='Installs', inplace=True, ascending=True)
print(type(no_of_installations_per_category))
print(f"No. of installations at each category is:")
print(f"{no_of_installations_per_category[:10]}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# No. of installations at each category is:
#                      Installs
# Category
# EVENTS               15949410
# BEAUTY               26916200
# PARENTING            31116110
# MEDICAL              39162676
# COMICS               44931100
# LIBRARIES_AND_DEMO   52083000
# AUTO_AND_VEHICLES    53129800
# HOUSE_AND_HOME       97082000
# ART_AND_DESIGN      114233100
# DATING              140912410

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
import plotly.express as px

bar = px.bar(x=no_of_apps_per_category[0:10].index,
       y=no_of_apps_per_category[0:10].values)

bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
print(no_of_installations_per_category[:10])
# Out:
#                      Installs
# Category
# EVENTS               15949410
# BEAUTY               26916200
# PARENTING            31116110
# MEDICAL              39162676
# COMICS               44931100
# LIBRARIES_AND_DEMO   52083000
# AUTO_AND_VEHICLES    53129800
# HOUSE_AND_HOME       97082000
# ART_AND_DESIGN      114233100
# DATING              140912410

# %%
h_bar = px.bar(x=no_of_installations_per_category.Installs,
               y=no_of_installations_per_category.index,
               orientation='h')
h_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
h_bar = px.bar(x=no_of_installations_per_category.Installs,
               y=no_of_installations_per_category.index,
               orientation='h',
               title='No of Installations per category')
h_bar.update_layout(xaxis_title = 'No of downloads', yaxis_title = 'Category')
h_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
no_of_installations_per_category.head()
# Out:
#            Installs
# Category
# EVENTS     15949410
# BEAUTY     26916200
# PARENTING  31116110
# MEDICAL    39162676
# COMICS     44931100

# %%
no_of_installations_per_category.loc['FAMILY'].values[0]
# Out:
# 4437554490

# %%
no_of_installations_per_category.loc['FAMILY']['Installs']
# Out:
# 4437554490

# %%
no_of_apps_per_category.head()
no_of_apps_per_category.index
no_of_apps_per_category.loc['FAMILY']
# Out:
# 1606

# %%
new_data=[]
#df_apps_and_installations.columns = ['Category', 'App Count', 'No. of Downloads']
for index in no_of_apps_per_category.index:
  new_data .append([index, no_of_apps_per_category.loc[index], no_of_installations_per_category.loc[index].values[0]])

df_apps_and_installations = pd.DataFrame(new_data, columns=['Category','App Count', 'No. of downloads'])

# %%
print(df_apps_and_installations[:4])
# Out:
#        Category  App Count  No. of downloads
# 0        FAMILY       1606        4437554490
# 1          GAME        910       13858762717
# 2         TOOLS        719        8099724500
# 3  PRODUCTIVITY        301        5788070180

# %%
scatter = px.scatter(df_apps_and_installations, # data
                    x='App Count', # column name
                    y='No. of downloads',
                    title='Category Concentration',
                    size='App Count',
                    hover_name=df_apps_and_installations.Category,
                    color='No. of downloads')
scatter.update_layout(xaxis_title="Number of Apps (Lower=More Concentrated)",
                      yaxis_title="No. of downloads",
                      yaxis=dict(type='log'))

scatter.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
df_non_duplicates.Genres.nunique()
# Out:
# 114

# %%
df_non_duplicates.Genres.value_counts().sample(5)
# Out:
# Strategy;Action & Adventure      2
# Food & Drink                    94
# Sports                         266
# Word                            22
# Strategy;Education               1
# Name: Genres, dtype: int64

# %%
split_genres = df_non_duplicates.Genres.str.split(';', expand=True)
print(split_genres.sample(5))
# Out:
#                             0     1
# 4773                    Tools  None
# 4462                   Social  None
# 2060  Video Players & Editors  None
# 4169                    Tools  None
# 2251            Entertainment  None

# %%
stacked_genres = split_genres.stack()
print(stacked_genres.sample(5))
# Out:
# 461   0           Medical
# 6613  0    Travel & Local
# 4076  0     Entertainment
# 1347  0         Lifestyle
# 2773  0            Events
# dtype: object

# %%
stacked_genres.values
# Out:
# array(['Medical', 'Arcade', 'Arcade', ..., 'Video Players & Editors',
#        'News & Magazines', 'Arcade'], dtype=object)

# %%
num_genres=stacked_genres.value_counts().sort_values(ascending=False)[:10]

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
import plotly.express as px
hbar_1 = px.bar(x=num_genres.index,
                y=num_genres.values,
                title='No.of apps per genre',
                color=num_genres.values,
                color_continuous_scale='Agsunset')

hbar_1.update_layout(xaxis_title='Genre',
yaxis_title='Number of Apps',
coloraxis_showscale=False)

hbar_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
df_free_vs_paid = df_apps_clean.groupby(["Category", "Type"], as_index=False).agg({'App': pd.Series.count})
df_free_vs_paid.head()
# Out:
#             Category  Type  App
# 0     ART_AND_DESIGN  Free   59
# 1     ART_AND_DESIGN  Paid    3
# 2  AUTO_AND_VEHICLES  Free   72
# 3  AUTO_AND_VEHICLES  Paid    1
# 4             BEAUTY  Free   42

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
g_bar = px.bar(df_free_vs_paid,
               x='Category',
               y='App',
               title='Free vs Paid Apps by Category',
               color='Type',
               barmode='group')

g_bar.update_layout(xaxis_title='Category',
                    yaxis_title='Number of Apps',
                    xaxis={'categoryorder':'total descending'},
                    yaxis=dict(type='log'))

g_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
box = px.box(df_non_duplicates,
             y='Installs',
             x='Type',
             color='Type',
             notched=True,
             points='all',
             title='How Many Downloads are Paid Apps Giving Up?')

box.update_layout(yaxis=dict(type='log'))

box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
df_paid_apps = df_non_duplicates[df_non_duplicates['Type'] == 'Paid']
box = px.box(df_paid_apps,
             x='Category',
             y='Revenue',
             title='How Much Can Paid Apps Earn?')

box.update_layout(xaxis_title='Category',
                  yaxis_title='Paid App Ballpark Revenue',
                  xaxis={'categoryorder':'min ascending'},
                  yaxis=dict(type='log'))


box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.

# %%
df_paid_apps.Price.median()
# Out:
# 2.99

# %%
box = px.box(df_paid_apps,
             x='Category',
             y="Price",
             title='Price per Category')

box.update_layout(xaxis_title='Category',
                  yaxis_title='Paid App Price',
                  xaxis={'categoryorder':'max descending'},
                  yaxis=dict(type='log'))

box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
